# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv('athletes/bios.csv')

df
# Out:
#                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
# 145499                Non-starter • Administrator    Male
#
#                                                 Full name  \
# 0       François Joseph Marie Antoine "Jean-François"•...
# 1                                 Arnaud Benjamin•Boetsch
# 2                             Jean Laurent Robert•Borotra
# ...

# %% [markdown]
# # What should we clean up ??

# %% [markdown]
# - [x] Get rid of extra columns
# - [x] Split Height/Weight
# - [x] Parse our dates from 'Born' & 'Died column
# - [] Parse out city, region, and country from 'Born' column
# - [] Get rid of bullet points

# %%
df.info
# Out:
# <bound method DataFrame.info of                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
# 145499                Non-starter • Administrator    Male
#
#                                                 Full name  \
# 0       François Joseph Marie Antoine "Jean-François"•...
# 1                                 Arnaud Benjamin•Boetsch
# 2                             Jean Laurent Robert•Borotra
# ...

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# ...

# %%
len(df)
# Out:
# 145500

# %%
len(df[df['Used name'].str.contains("•")])
# Out:
# 145500

# %%
df['name'] = df['Used name'].str.replace('•', ' ')

# %%
df.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# ...

# %%
# df.drop(columns=['height', 'weight'])
df[['height_cm', 'weight_kg']] = df['Measurements'].str.split('/', expand=True)

df['weight_kg'].fillna(df['height_cm'], inplace=True)

df['height_cm'] = pd.to_numeric(df['height_cm'].str.strip(r' cm'), errors='coerce')
df['weight_kg'] = pd.to_numeric(df['weight_kg'].str.strip(r' kg'), errors='coerce')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18044\3987746438.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['weight_kg'].fillna(df['height_cm'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Roles          145500 non-null  object
#  1   Sex            145500 non-null  object
#  2   Full name      145500 non-null  object
#  3   Used name      145500 non-null  object
#  4   Born           143772 non-null  object
#  5   Died           34042 non-null   object
#  6   NOC            145499 non-null  object
#  7   athlete_id     145500 non-null  int64
#  8   Measurements   107833 non-null  object
#  9   Affiliations   95832 non-null   object
#  10  Nick/petnames  9145 non-null    object
#  11  Title(s)       399 non-null     object
#  12  Other names    7167 non-null    object
#  13  Nationality    8259 non-null    object
#  14  Original name  30739 non-null   object
#  15  Name order     7844 non-null    object
#  16  name           145500 non-null  object
# ...

# %%
# check to make sure all values have '/' 

# df[~df['Measurements'].str.contains('/', na=False) & df['Measurements'].notna()] 

small_data = pd.DataFrame(['183 cm', '180 cm / 150 kg', '190 cm / 80 kg', '100 kg'], columns = ["Measurements"])
small_data[['height_cm', 'weight_kg']] = df['Measurements'].str.split('/', expand=True)

small_data['weight_kg'].fillna(small_data['height_cm'], inplace=True)

small_data['height_cm'] = pd.to_numeric(small_data['height_cm'].str.strip(r' cm'), errors='coerce')
small_data['weight_kg'] = pd.to_numeric(small_data['weight_kg'].str.strip(r' kg'), errors='coerce')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18044\2993893016.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   small_data['weight_kg'].fillna(small_data['height_cm'], inplace=True)

# %%
small_data.head()
# Out:
#       Measurements  height_cm  weight_kg
# 0           183 cm        NaN        NaN
# 1  180 cm / 150 kg      183.0       76.0
# 2   190 cm / 80 kg      183.0       76.0
# 3           100 kg      168.0       64.0

# %%
# df['height_cm'] = df['height_cm'].strip(' cm')

# %%
# Get rid of 'cm' and the 'kg' from our new columns 
# df['height_cm'] = df['height_cm'].str.extract(r'(/d+)')
# df['weight_kg'] = df['weight_kg'].str.strip(' kg')

# %%
df.sort_values('height_cm', ascending=False)
# Out:
#                                     Roles     Sex  \
# 89070   Competed in Olympic Games • Other    Male
# 5781            Competed in Olympic Games    Male
# 6978            Competed in Olympic Games    Male
# 89075           Competed in Olympic Games    Male
# 120266          Competed in Olympic Games    Male
# ...                                   ...     ...
# 145490          Competed in Olympic Games    Male
# 145491          Competed in Olympic Games    Male
# 145492          Competed in Olympic Games    Male
# 145493          Competed in Olympic Games  Female
# 145499        Non-starter • Administrator    Male
#
#                              Full name              Used name  \
# 89070                         Yao•Ming               Yao•Ming
# 5781     Thomas Loren "Tommy"•Burleson         Tommy•Burleson
# 6978             Arvydas Romas•Sabonis        Arvydas•Sabonis
# 89075         Roberto•Dueñas Hernández         Roberto•Dueñas
# ...

# %% [markdown]
# # Parse our dates from 'Born' & 'Died column

# %%
small_data = pd.DataFrame(['1895 in Scotland', '12 December 1900 in Boston'], columns=['Born'])

date_pattern = r'(\d+ \w+ \d{4}|\d{4})'

small_data['born date'] = small_data['Born'].str.extract(date_pattern)

# %%
df[~df['Born'].str.match(date_pattern, na=False) & df['Born'].notna()]
# Out:
#                             Roles     Sex                     Full name  \
# 91      Competed in Olympic Games    Male         Lionel Hunter•Escombe
# 179     Competed in Olympic Games    Male         Pantelis•Papadopoulos
# 552     Competed in Olympic Games  Female  Emily Jane•Rushton (Ormrod-)
# 561     Competed in Olympic Games  Female                Hilda•Williams
# 667     Competed in Olympic Games  Female                   Marie•Jones
# ...                           ...     ...                           ...
# 118318  Competed in Olympic Games    Male       J. Edward "Eddie"•Heron
# 118344  Competed in Olympic Games  Female               Lilo•Mund Borgs
# 124915  Competed in Olympic Games    Male           William•Taylor, Jr.
# 126482  Competed in Olympic Games    Male      Cornelius•von Lubowiecki
# 135276  Competed in Olympic Games    Male             Louis•Dufour, Sr.
#
#                        Used name  \
# 91                Lionel•Escombe
# ...

# %%
small_data
# Out:
#                Born         born date
# 0              1895              1895
# 1  12 December 1900  12 December 1900

# %%
date_pattern = r'(\d+ \w+ \d{4}|\d{4})'

df['born_date'] = (df['Born'].str.extract(date_pattern))
df['born_year'] = df['Born'].str.extract(r'(\d{4})')

df['born_date'] = pd.to_datetime(df['born_date'], format="mixed", errors='coerce')
df['born_year'] = pd.to_numeric(df['born_year'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Roles          145500 non-null  object
#  1   Sex            145500 non-null  object
#  2   Full name      145500 non-null  object
#  3   Used name      145500 non-null  object
#  4   Born           143772 non-null  object
#  5   Died           34042 non-null   object
#  6   NOC            145499 non-null  object
#  7   athlete_id     145500 non-null  int64
#  8   Measurements   107833 non-null  object
#  9   Affiliations   95832 non-null   object
#  10  Nick/petnames  9145 non-null    object
#  11  Title(s)       399 non-null     object
#  12  Other names    7167 non-null    object
#  13  Nationality    8259 non-null    object
#  14  Original name  30739 non-null   object
#  15  Name order     7844 non-null    object
#  16  name           145500 non-null  object
# ...

# %%
df.born_date.dt.month
# Out:
# 0         12.0
# 1          4.0
# 2          8.0
# 3          5.0
# 4          4.0
#           ...
# 145495     1.0
# 145496     9.0
# 145497     5.0
# 145498     5.0
# 145499     7.0
# Name: born_date, Length: 145500, dtype: float64

# %%
df['died_date'] = df['Died'].str.extract(date_pattern)
df['died_date'] = pd.to_datetime(df['died_date'], format="mixed", errors='coerce')

# %%
df.info()
# print(df.sort_values['died_date', ascending=False])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Roles          145500 non-null  object
#  1   Sex            145500 non-null  object
#  2   Full name      145500 non-null  object
#  3   Used name      145500 non-null  object
#  4   Born           143772 non-null  object
#  5   Died           34042 non-null   object
#  6   NOC            145499 non-null  object
#  7   athlete_id     145500 non-null  int64
#  8   Measurements   107833 non-null  object
#  9   Affiliations   95832 non-null   object
#  10  Nick/petnames  9145 non-null    object
#  11  Title(s)       399 non-null     object
#  12  Other names    7167 non-null    object
#  13  Nationality    8259 non-null    object
#  14  Original name  30739 non-null   object
#  15  Name order     7844 non-null    object
#  16  name           145500 non-null  object
# ...

# %%
df.died_date
# Out:
# 0        1960-10-02
# 1               NaT
# 2        1994-07-17
# 3        1978-03-20
# 4        1930-07-25
#             ...
# 145495          NaT
# 145496          NaT
# 145497          NaT
# 145498   1986-03-18
# 145499   2003-10-20
# Name: died_date, Length: 145500, dtype: datetime64[ns]

# %%
df['born_year']
# Out:
# 0         1886.0
# 1         1969.0
# 2         1898.0
# 3         1895.0
# 4         1878.0
#            ...
# 145495    2002.0
# 145496    1999.0
# 145497    1998.0
# 145498    1899.0
# 145499    1913.0
# Name: born_year, Length: 145500, dtype: float64

# %% [markdown]
# # Get city, regeon and Country from Born column
